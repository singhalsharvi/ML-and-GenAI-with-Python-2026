# %%
#1. Sum of first 10 natural numbers
sum=0
i=1
while i<=10 :
  sum=sum+i
  i+=1

print(sum)
# Out:
# 55

# %%
#2. Factorial of a number
num= int(input("Enter the number: "))
i=num
fact=1
while i>=1 :
  fact=fact*i
  i-=1

print(fact)
# Out:
# Enter the number: 7
# 5040

# %%
#3. Print fibonacci series
n = int(input("Enter number of terms: "))

a = 0
b = 1

print("Fibonacci Series:")

for i in range(n):
    print(a, end=" ")

    c = a + b
    a = b
    b = c
# Out:
# Enter number of terms: 7
# Fibonacci Series:
# 0 1 1 2 3 5 8

# %%
#4. Largest among 3 numbers
num1=int(input("Enter the first number: "))
num2=int(input("Enter the second number: "))
num3=int(input("Enter the third number: "))
list=[num1,num2,num3]
max=num1
for i in list:
  if i>max:
    max=i

print("Max element is:", max)
# Out:
# Enter the first number: 34
# Enter the second number: 67
# Enter the third number: 567
# Max element is: 567

# %%
#8.
name = input("Enter your name: ")
roll_no = input("Enter roll number: ")
college = input("Enter your college name: ")
branch = input("Enter your branch:")
subjects=int(input("Enter the number of subjects:"))

total_marks=0

for i in range(subjects):
  marks=float(input(f"Enter the marks of subject{i+1}:"))
  total_marks=total_marks+marks

percentage=total_marks/subjects
print("percentage is:", percentage)

if percentage>=90:
  grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "Fail"

# Display Result
print("\n----- Student Result -----")
print("Student Name:", name)
print("Roll Number:", roll_no)
print("Total Marks:", total_marks)
print("Percentage:", round(percentage, 2), "%")
print("Grade:", grade)
# Out:
# Enter your name: Sharvi
# Enter roll number: 183
# Enter your college name: IGDTUW
# Enter your branch:CSE
# Enter the number of subjects:6
# Enter the marks of subject1:90
# Enter the marks of subject2:90
# Enter the marks of subject3:91
# Enter the marks of subject4:92
# Enter the marks of subject5:85
# Enter the marks of subject6:89
# percentage is: 89.5
#
# ----- Student Result -----
# Student Name: Sharvi
# Roll Number: 183
# Total Marks: 537.0
# Percentage: 89.5 %
# Grade: A
